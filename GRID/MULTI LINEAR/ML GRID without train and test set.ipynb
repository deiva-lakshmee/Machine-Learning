# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
 # Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.linear_model import Ridge  # Import Ridge for Linear Regression with Regularization
from sklearn.model_selection import GridSearchCV

# Define the parameter grid for Ridge Regression
param_grid = {
    'alpha': [0.1, 1.0, 10.0, 100.0],  # Regularization strength
    'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']  # Different solvers
}

# %%
# Initialize GridSearchCV with Ridge Regression
grid = GridSearchCV(Ridge(), param_grid, refit=True, verbose=3, n_jobs=-1, cv=5)

# Fitting the model for grid search on the training data
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# GridSearchCV(cv=5, estimator=Ridge(), n_jobs=-1,
#              param_grid={'alpha': [0.1, 1.0, 10.0, 100.0],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr',
#                                     'sparse_cg', 'sag', 'saga']},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test)
# print classification report
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'alpha': 10.0, 'solver': 'saga'}: 0.785538244681357

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0        0.013893      0.002244         0.000602        0.001203         0.1
# 1        0.012174      0.006560         0.001970        0.003407         0.1
# 2        0.001386      0.001215         0.000522        0.000640         0.1
# 3        0.002402      0.000483         0.000819        0.000687         0.1
# 4        0.002770      0.002962         0.001238        0.001776         0.1
# 5        0.003972      0.004395         0.000000        0.000000         0.1
# 6        0.002928      0.001631         0.000618        0.001237         0.1
# 7        0.000302      0.000603         0.000000        0.000000         1.0
# 8        0.001390      0.001703         0.001370        0.001678         1.0
# 9        0.000402      0.000804         0.000402        0.000804         1.0
# 10       0.001897      0.003793         0.000000        0.000000         1.0
# 11       0.001202      0.002404         0.001202        0.002404         1.0
# 12       0.001202      0.002404         0.000000        0.000000         1.0
# 13       0.007150      0.005841         0.001726        0.002903         1.0
# 14       0.002346      0.004692         0.000112        0.000224        10.0
# 15       0.001502      0.003004         0.001502        0.003004        10.0
# 16       0.000000      0.000000         0.000000        0.000000        10.0
# 17       0.002272      0.004545         0.000112        0.000224        10.0
# 18       0.004647      0.003948         0.000579        0.000830        10.0
# 19       0.006287      0.003417         0.000172        0.000344        10.0
# 20       0.005308      0.003326         0.000611        0.000788        10.0
# 21       0.002792      0.001232         0.000575        0.000829       100.0
# 22       0.002438      0.000962         0.000326        0.000435       100.0
# 23       0.002695      0.000641         0.000280        0.000560       100.0
# 24       0.002925      0.002609         0.000000        0.000000       100.0
# 25       0.000000      0.000000         0.000000        0.000000       100.0
# 26       0.002435      0.004870         0.006051        0.004620       100.0
# 27       0.001692      0.001590         0.000161        0.000321       100.0
#
#    param_solver                                   params  split0_test_score  \
# 0          auto         {'alpha': 0.1, 'solver': 'auto'}           0.707281
# 1           svd          {'alpha': 0.1, 'solver': 'svd'}           0.707281
# 2      cholesky     {'alpha': 0.1, 'solver': 'cholesky'}           0.707281
# 3          lsqr         {'alpha': 0.1, 'solver': 'lsqr'}           0.707282
# 4     sparse_cg    {'alpha': 0.1, 'solver': 'sparse_cg'}           0.707282
# 5           sag          {'alpha': 0.1, 'solver': 'sag'}           0.707295
# 6          saga         {'alpha': 0.1, 'solver': 'saga'}           0.707275
# 7          auto         {'alpha': 1.0, 'solver': 'auto'}           0.707396
# 8           svd          {'alpha': 1.0, 'solver': 'svd'}           0.707396
# 9      cholesky     {'alpha': 1.0, 'solver': 'cholesky'}           0.707396
# 10         lsqr         {'alpha': 1.0, 'solver': 'lsqr'}           0.707397
# 11    sparse_cg    {'alpha': 1.0, 'solver': 'sparse_cg'}           0.707397
# 12          sag          {'alpha': 1.0, 'solver': 'sag'}           0.707393
# 13         saga         {'alpha': 1.0, 'solver': 'saga'}           0.707400
# 14         auto        {'alpha': 10.0, 'solver': 'auto'}           0.708399
# 15          svd         {'alpha': 10.0, 'solver': 'svd'}           0.708399
# 16     cholesky    {'alpha': 10.0, 'solver': 'cholesky'}           0.708399
# 17         lsqr        {'alpha': 10.0, 'solver': 'lsqr'}           0.708400
# 18    sparse_cg   {'alpha': 10.0, 'solver': 'sparse_cg'}           0.708400
# 19          sag         {'alpha': 10.0, 'solver': 'sag'}           0.708390
# 20         saga        {'alpha': 10.0, 'solver': 'saga'}           0.708404
# 21         auto       {'alpha': 100.0, 'solver': 'auto'}           0.706683
# 22          svd        {'alpha': 100.0, 'solver': 'svd'}           0.706683
# 23     cholesky   {'alpha': 100.0, 'solver': 'cholesky'}           0.706683
# 24         lsqr       {'alpha': 100.0, 'solver': 'lsqr'}           0.706683
# 25    sparse_cg  {'alpha': 100.0, 'solver': 'sparse_cg'}           0.706683
# 26          sag        {'alpha': 100.0, 'solver': 'sag'}           0.706686
# 27         saga       {'alpha': 100.0, 'solver': 'saga'}           0.706676
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.690693           0.757148           0.710842
# 1            0.690693           0.757148           0.710842
# 2            0.690693           0.757148           0.710842
# 3            0.690692           0.757147           0.710847
# 4            0.690692           0.757147           0.710847
# 5            0.690698           0.757156           0.710829
# 6            0.690697           0.757147           0.710837
# 7            0.690706           0.757029           0.711055
# 8            0.690706           0.757029           0.711055
# 9            0.690706           0.757029           0.711055
# 10           0.690705           0.757028           0.711060
# 11           0.690705           0.757028           0.711060
# 12           0.690742           0.757003           0.711041
# 13           0.690705           0.757038           0.711064
# 14           0.690705           0.755727           0.712999
# 15           0.690705           0.755727           0.712999
# 16           0.690705           0.755727           0.712999
# 17           0.690704           0.755726           0.713004
# 18           0.690704           0.755726           0.713004
# 19           0.690719           0.755712           0.712999
# 20           0.690723           0.755718           0.713006
# 21           0.681053           0.734424           0.717830
# 22           0.681053           0.734424           0.717830
# 23           0.681053           0.734424           0.717830
# 24           0.681053           0.734414           0.717832
# 25           0.681053           0.734414           0.717832
# 26           0.681051           0.734428           0.717832
# 27           0.681062           0.734421           0.717827
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.714428         0.716078        0.022085               18
# 1            0.714428         0.716078        0.022085               18
# 2            0.714428         0.716078        0.022085               18
# 3            0.714428         0.716079        0.022084               16
# 4            0.714428         0.716079        0.022084               17
# 5            0.714434         0.716082        0.022086               15
# 6            0.714425         0.716076        0.022084               21
# 7            0.714294         0.716096        0.022020               11
# 8            0.714294         0.716096        0.022020               11
# 9            0.714294         0.716096        0.022020               11
# 10           0.714294         0.716097        0.022020                9
# 11           0.714294         0.716097        0.022020               10
# 12           0.714292         0.716094        0.022003               14
# 13           0.714298         0.716101        0.022023                8
# 14           0.712845         0.716135        0.021423                4
# 15           0.712845         0.716135        0.021423                4
# 16           0.712845         0.716135        0.021423                4
# 17           0.712845         0.716136        0.021423                2
# 18           0.712845         0.716136        0.021423                3
# 19           0.712849         0.716134        0.021415                7
# 20           0.712845         0.716139        0.021415                1
# 21           0.690618         0.706122        0.019012               24
# 22           0.690618         0.706122        0.019012               23
# 23           0.690618         0.706122        0.019012               24
# 24           0.690618         0.706120        0.019009               26
# 25           0.690618         0.706120        0.019009               26
# 26           0.690619         0.706123        0.019014               22
# 27           0.690609         0.706119        0.019010               28

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 27
# BMI: 12
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#␣change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[143824.95774181]
